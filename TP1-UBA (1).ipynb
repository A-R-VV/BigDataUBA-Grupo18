# %% [markdown]
# # Big Data y Machine Learning (UBA) -  2025
#
# ## Trabajo Práctico 1: Jugando con APIs y WebScraping

# %% [markdown]
# ### Reglas de formato y presentación
# - El trabajo debe estar debidamente documentado comentado (utilizando #) para que tanto los docentes como sus compañeros puedan comprender el código fácilmente.
#
# - El mismo debe ser completado en este Jupyter Notebook y entregado como tal, es decir en un archivo .ipynb

# %% [markdown]
# ### Fecha de entrega:
# Viernes 4 de Abril a las 13:00 hs

# %% [markdown]
# ### Modalidad de entrega
# - Al finalizar el trabajo práctico deben hacer un último <i>commit</i> en su repositorio de GitHub llamado “Entrega final del tp”.
# - Asegurense de haber creado una carpeta llamada TP1. Este Jupyter Notebook y el correspondiente al TP1 deben estar dentro de esa carpeta.
# - También deben enviar el link de su repositorio -para que pueda ser clonado y corregido- a mi correo 25RO35480961@campus.economicas.uba.ar. Usar de asunto de email <i>"Big Data - TP 1 - Grupo #"</i> y nombrar el archivo <i>"TP1_Grupo #"</i> donde # es el número de grupo que le fue asignado.
# - La última versión en el repositorio es la que será evaluada. Por lo que es importante que:
#     - No envien el correo hasta no haber terminado y estar seguros de que han hecho el <i>commit y push</i> a la versión final que quieren entregar.
#     - No hagan nuevos <i>push</i> despues de haber entregado su versión final. Esto generaría confusión acerca de que versión es la que quieren que se les corrija.
# - En resumen, la carpeta del repositorio debe incluir:
#     - El codigo
#     - Un documento Word (Parte A) donde esten las figuras y una breve descripción de las mismas.
#     - El excel con los links webscrappeados (Parte B)

# %% [markdown]
# ### Parte A

# %% [markdown]
# #### Ejercicio 1 - Jugando con APIs
# Usando la API del Banco Mundial [link](https://wbdata.readthedocs.io/en/stable/) , obtener dos series de indicadores para dos paises a elección en una consulta de búsqueda. Pueden buscar serie de indicadores de su interés.

# %%
# Resolver acá

# %%
import wbdata
import pandas as pd

# Paso 1: Configuración de países e indicadores
paises = ["AR", "MEX"]
indicadores = {"SP.POP.TOTL": "Población total", "NY.GDP.PCAP.CD": "PIB per cápita (USD actuales)"}

# Paso 2: Obtención de datos del Banco Mundial
datos = wbdata.get_dataframe(indicadores, country=paises)

# Paso 3: Separar datos por país (ajustado para el índice)
datos_argentina = datos.loc[datos.index.get_level_values('country') == 'Argentina']
datos_mexico = datos.loc[datos.index.get_level_values('country') == 'Mexico']

# Paso 4: Mostrar los DataFrames resultantes
print("Datos de Argentina:")
print(datos_argentina)

print("\nDatos de México:")
print(datos_mexico)
# Out:
# Datos de Argentina:
#                 Población total  PIB per cápita (USD actuales)
# country   date
# Argentina 2023       45538401.0                   14187.482725
#           2022       45407904.0                   13935.681111
#           2021       45312281.0                   10738.017922
#           2020       45191965.0                    8535.599380
#           2019       44973465.0                    9955.974787
# ...                         ...                            ...
#           1964       21769453.0                    1176.200862
#           1963       21421705.0                     852.972425
#           1962       21072538.0                    1160.306598
#           1961       20726276.0                            NaN
#           1960       20386045.0                            NaN
#
# [64 rows x 2 columns]
#
# Datos de México:
#               Población total  PIB per cápita (USD actuales)
# country date
# Mexico  2023      129739759.0                   13790.024343
#         2022      128613117.0                   11385.407076
#         2021      127648148.0                   10314.050674
#         2020      126799054.0                    8841.270750
#         2019      125762982.0                   10369.555357
# ...                       ...                            ...
#         1964       41772049.0                     480.704214
#         1963       40424065.0                     419.552066
#         1962       39129200.0                     388.456702
#         1961       37890118.0                     373.712217
#         1960       36724615.0                     355.075200
#
# [64 rows x 2 columns]

# %% [markdown]
# #### Ejercicio 2 - Repaso de Pandas
# Realicen una estadistica descriptiva de ambas series de indicadores comparando los dos países.

# %%
import wbdata
import pandas as pd

# Paso 1: Configuración de países e indicadores
paises = ["AR", "MEX"]
indicadores = {"SP.POP.TOTL": "Población total", "NY.GDP.PCAP.CD": "PIB per cápita (USD actuales)"}

# Paso 2: Obtención de datos del Banco Mundial
datos = wbdata.get_dataframe(indicadores, country=paises)

# Paso 3: Separar datos por país (ajustado para el índice)
datos_argentina = datos.loc[datos.index.get_level_values('country') == 'Argentina']
datos_mexico = datos.loc[datos.index.get_level_values('country') == 'Mexico']

# %%
# Estadísticas descriptivas para Argentina
estadisticas_argentina = datos_argentina.describe()

# Estadísticas descriptivas para México
estadisticas_mexico = datos_mexico.describe()

# %%
print("Estadísticas descriptivas para Argentina:")
print(estadisticas_argentina)

print("\nEstadísticas descriptivas para México:")
print(estadisticas_mexico)
# Out:
# Estadísticas descriptivas para Argentina:
#        Población total  PIB per cápita (USD actuales)
# count     6.400000e+01                      62.000000
# mean      3.327053e+07                    5868.081617
# std       7.941125e+06                    4191.377724
# min       2.038604e+07                     852.972425
# 25%       2.618024e+07                    2408.923244
# 50%       3.346191e+07                    4278.677142
# 75%       4.011861e+07                    8201.802913
# max       4.553840e+07                   14532.500931
#
# Estadísticas descriptivas para México:
#        Población total  PIB per cápita (USD actuales)
# count     6.400000e+01                      64.000000
# mean      8.464321e+07                    5097.053128
# std       2.858341e+07                    3999.842471
# min       3.672462e+07                     355.075200
# 25%       6.022973e+07                    1427.779195
# 50%       8.523769e+07                    4006.511426
# 75%       1.091743e+08                    8905.434057
# max       1.297398e+08                   13790.024343

# %%
# Resolver acá

# %%
import wbdata
import pandas as pd

# Paso 1: Configuración de países e indicadores
paises = ["AR", "MEX"]
indicadores = {"SP.POP.TOTL": "Población total", "NY.GDP.PCAP.CD": "PIB per cápita (USD actuales)"}

# Paso 2: Obtención de datos del Banco Mundial
datos = wbdata.get_dataframe(indicadores, country=paises)

# Paso 3: Separar datos por país (ajustado para el índice)
datos_argentina = datos.loc[datos.index.get_level_values('country') == 'Argentina']
datos_mexico = datos.loc[datos.index.get_level_values('country') == 'Mexico']

# Paso 4: Concatenar los DataFrames para el análisis
df = pd.concat([datos_argentina, datos_mexico])

# Paso 5: Verificar que tenemos datos
if not df.empty:
    print("\n ESTADÍSTICAS DESCRIPTIVAS POR PAÍS E INDICADOR\n")
    
    # Paso 6: Configurar pandas para mostrar más decimales
    pd.set_option('display.float_format', '{:.2f}'.format)
    
    # Paso 7: Estadísticas generales
    print(" Estadísticas generales para todos los datos:")
    print(df.describe())
    
    # Paso 8: Estadísticas por país
    for pais in df.index.get_level_values('country').unique():
        print(f"\n Estadísticas para {pais}:")
        print(df.loc[df.index.get_level_values('country') == pais].describe())
    
    # Paso 9: Comparación directa de promedios
    print("\n COMPARACIÓN DIRECTA (PROMEDIOS):")
    comparacion = df.groupby(level='country').mean(numeric_only=True)
    print(comparacion)
    
    # Paso 10: Diferencia porcentual entre países (ajustado para Argentina y México)
    print("\n DIFERENCIA PORCENTUAL (MEX/AR - 1):")
    diff = (comparacion.loc['Mexico'] / comparacion.loc['Argentina'] - 1) * 100
    print(diff.round(2).astype(str) + " %")
else:
    print("No se encontraron datos para los países seleccionados.")
# Out:
#  ESTADÍSTICAS DESCRIPTIVAS POR PAÍS E INDICADOR
#
#  Estadísticas generales para todos los datos:
#        Población total  PIB per cápita (USD actuales)
# count           128.00                         126.00
# mean       58956872.59                        5476.45
# std        33189678.71                        4097.09
# min        20386045.00                         355.08
# 25%        33577718.75                        1902.93
# 50%        44459000.00                        4202.22
# 75%        84834131.25                        8637.72
# max       129739759.00                       14532.50
#
#  Estadísticas para Argentina:
#        Población total  PIB per cápita (USD actuales)
# count            64.00                          62.00
# mean       33270532.19                        5868.08
# std         7941124.91                        4191.38
# min        20386045.00                         852.97
# 25%        26180239.00                        2408.92
# 50%        33461910.50                        4278.68
# 75%        40118609.25                        8201.80
# max        45538401.00                       14532.50
#
#  Estadísticas para Mexico:
#        Población total  PIB per cápita (USD actuales)
# count            64.00                          64.00
# mean       84643212.98                        5097.05
# std        28583408.78                        3999.84
# min        36724615.00                         355.08
# 25%        60229734.00                        1427.78
# 50%        85237690.50                        4006.51
# 75%       109174342.00                        8905.43
# max       129739759.00                       13790.02
#
#  COMPARACIÓN DIRECTA (PROMEDIOS):
#            Población total  PIB per cápita (USD actuales)
# country
# Argentina      33270532.19                        5868.08
# Mexico         84643212.98                        5097.05
#
#  DIFERENCIA PORCENTUAL (MEX/AR - 1):
# Población total                  154.41 %
# PIB per cápita (USD actuales)    -13.14 %
# dtype: object

# %%
import wbdata
import pandas as pd

# Paso 1: Configuración de países e indicadores
paises = ["AR", "MEX"]
indicadores = {"SP.POP.TOTL": "Población total", "NY.GDP.PCAP.CD": "PIB per cápita (USD actuales)"}

# Paso 2: Obtención de datos del Banco Mundial
datos = wbdata.get_dataframe(indicadores, country=paises)

# Paso 3: Separar datos por país (ajustado para el índice)
datos_argentina = datos.loc[datos.index.get_level_values('country') == 'Argentina']
datos_mexico = datos.loc[datos.index.get_level_values('country') == 'Mexico']

# Paso 4: Concatenar los DataFrames para el análisis
df = pd.concat([datos_argentina, datos_mexico])

# Paso 5: Verificar que tenemos datos
if not df.empty:
    print("\n ESTADÍSTICAS DESCRIPTIVAS POR PAÍS E INDICADOR \n")  # Añadimos emojis para hacerlo más visual
    
    # Paso 6: Configurar pandas para mostrar más decimales
    pd.set_option('display.float_format', '{:.2f}'.format)
    
    # Paso 7: Estadísticas generales
    print(" Estadísticas generales para todos los datos:")
    display(df.describe())  # Usamos display() para mostrar el DataFrame en Jupyter Notebook
    
    # Paso 8: Estadísticas por país
    for pais in df.index.get_level_values('country').unique():
        print(f"\n Estadísticas para {pais}:")
        display(df.loc[df.index.get_level_values('country') == pais].describe())  # Usamos display()
    
    # Paso 9: Comparación directa de promedios
    print("\n COMPARACIÓN DIRECTA (PROMEDIOS):")
    comparacion = df.groupby(level='country').mean(numeric_only=True)
    display(comparacion)  # Usamos display()
    
    # Paso 10: Diferencia porcentual entre países (ajustado para Argentina y México)
    print("\n DIFERENCIA PORCENTUAL (MEX/AR - 1):")
    diff = (comparacion.loc['Mexico'] / comparacion.loc['Argentina'] - 1) * 100
    display(diff.round(2).astype(str) + " %")  # Usamos display()
else:
    print("No se encontraron datos para los países seleccionados.")
# Out:
#  ESTADÍSTICAS DESCRIPTIVAS POR PAÍS E INDICADOR
#
#  Estadísticas generales para todos los datos:
#        Población total  PIB per cápita (USD actuales)
# count           128.00                         126.00
# mean       58956872.59                        5476.45
# std        33189678.71                        4097.09
# min        20386045.00                         355.08
# 25%        33577718.75                        1902.93
# 50%        44459000.00                        4202.22
# 75%        84834131.25                        8637.72
# max       129739759.00                       14532.50
#  Estadísticas para Argentina:
#        Población total  PIB per cápita (USD actuales)
# count            64.00                          62.00
# mean       33270532.19                        5868.08
# std         7941124.91                        4191.38
# min        20386045.00                         852.97
# 25%        26180239.00                        2408.92
# 50%        33461910.50                        4278.68
# 75%        40118609.25                        8201.80
# max        45538401.00                       14532.50
#  Estadísticas para Mexico:
#        Población total  PIB per cápita (USD actuales)
# count            64.00                          64.00
# mean       84643212.98                        5097.05
# std        28583408.78                        3999.84
# min        36724615.00                         355.08
# 25%        60229734.00                        1427.78
# 50%        85237690.50                        4006.51
# 75%       109174342.00                        8905.43
# max       129739759.00                       13790.02
#  COMPARACIÓN DIRECTA (PROMEDIOS):
#            Población total  PIB per cápita (USD actuales)
# country
# Argentina      33270532.19                        5868.08
# Mexico         84643212.98                        5097.05
#  DIFERENCIA PORCENTUAL (MEX/AR - 1):
# Población total                  154.41 %
# PIB per cápita (USD actuales)    -13.14 %
# dtype: object

# %% [markdown]
# #### Ejercicio 3 - Practicando con Matplotlib
# Armen dos gráficos distintos usando la librería Matplotlib (repasen Clase 4). Uno programandolo con el estilo *pyplot* y otro gráfico de estilo *orientada a objetos*

# %%
# Resolver acá estilo pyplot

# %%
import wbdata
import pandas as pd
import matplotlib.pyplot as plt

# Paso 1: Configuración de países e indicadores
paises = ["AR", "MEX"]
indicadores = {"SP.POP.TOTL": "Población total", "NY.GDP.PCAP.CD": "PIB per cápita (USD actuales)"}

# Paso 2: Obtención de datos del Banco Mundial
datos = wbdata.get_dataframe(indicadores, country=paises)

# Paso 3: Separar datos por país (ajustado para el índice)
datos_argentina = datos.loc[datos.index.get_level_values('country') == 'Argentina']
datos_mexico = datos.loc[datos.index.get_level_values('country') == 'Mexico']

# Paso 4: Convertir el índice de fechas a datetime
fechas_argentina = pd.to_datetime(datos_argentina.index.get_level_values('date'))
fechas_mexico = pd.to_datetime(datos_mexico.index.get_level_values('date'))

# Paso 5: Gráfico con estilo pyplot (corregido)
plt.figure(figsize=(10, 6))  # Tamaño del gráfico
plt.plot(fechas_argentina, datos_argentina[('PIB per cápita (USD actuales)')], label='Argentina')
plt.plot(fechas_mexico, datos_mexico[('PIB per cápita (USD actuales)')], label='México')
plt.title('PIB per cápita en Argentina y México')
plt.xlabel('Año')
plt.ylabel('PIB per cápita (USD)')
plt.legend()
plt.show()

# Paso 6: Gráfico con estilo orientado a objetos (corregido)
fig, ax = plt.subplots(figsize=(10, 6))  # Tamaño del gráfico

ultimo_anio_argentina = datos_argentina[('Población total')].iloc[-1]
ultimo_anio_mexico = datos_mexico[('Población total')].iloc[-1]

ax.bar(['Argentina', 'México'], [ultimo_anio_argentina, ultimo_anio_mexico])
ax.set_title('Población total en Argentina y México (último año)')
ax.set_ylabel('Población')
plt.show()

# %%
# Resolver acá estilo orientado-objetos 
# Tip: aprovechar este estilo de programar una figura para hacerlo más lindo

# %%
import wbdata
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Paso 1: Configuración de países e indicadores
paises = ["AR", "MEX"]
indicadores = {"SP.POP.TOTL": "Población total", "NY.GDP.PCAP.CD": "PIB per cápita (USD actuales)"}

# Paso 2: Obtención de datos del Banco Mundial
datos = wbdata.get_dataframe(indicadores, country=paises)

# Paso 3: Separar datos por país (ajustado para el índice)
datos_argentina = datos.loc[datos.index.get_level_values('country') == 'Argentina']
datos_mexico = datos.loc[datos.index.get_level_values('country') == 'Mexico']

# Paso 4: Convertir el índice de fechas a datetime
datos_argentina.index = pd.to_datetime(datos_argentina.index.get_level_values('date'))
datos_mexico.index = pd.to_datetime(datos_mexico.index.get_level_values('date'))

# Paso 5: Gráfico con estilo pyplot (corregido y mejorado)
plt.figure(figsize=(15, 7))  # Aumentar el tamaño del gráfico
plt.plot(datos_argentina.index, datos_argentina[('PIB per cápita (USD actuales)')], label='Argentina', marker='o')
plt.plot(datos_mexico.index, datos_mexico[('PIB per cápita (USD actuales)')], label='México', marker='o')
plt.title('PIB per cápita en Argentina y México')
plt.xlabel('Año')
plt.ylabel('PIB per cápita (USD)')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))  # Formato de fechas en el eje x
plt.gca().xaxis.set_major_locator(mdates.YearLocator(base=5))  # Mostrar un tick cada 5 años
plt.xticks(rotation=45)  # Rotar las etiquetas del eje x para mejor legibilidad
plt.grid(True)  # Añadir una cuadrícula al gráfico
plt.legend()
plt.tight_layout()  # Ajustar el diseño del gráfico para evitar superposiciones
plt.show()

# Paso 6: Gráfico con estilo orientado a objetos (corregido y mejorado)
fig, ax = plt.subplots(figsize=(12, 6))

ultimo_anio_argentina = datos_argentina[('Población total')].iloc[-1]
ultimo_anio_mexico = datos_mexico[('Población total')].iloc[-1]

ax.bar(['Argentina', 'México'], [ultimo_anio_argentina, ultimo_anio_mexico], color=['skyblue', 'salmon'])
ax.set_title('Población total en Argentina y México (último año)')
ax.set_ylabel('Población')
ax.grid(axis='y', linestyle='--')  # Añadir una cuadrícula al eje y
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Parte B

# %% [markdown]
# #### Ejercicio 4
# De la página de noticias del [diario La Nación](https://www.lanacion.com.ar/) o cualquier diario que les interese, utilicen herramientas de web scraping para obtener los **links** de las noticias de la portada. Guarden los links obtenidos en un dataframe y expórtenlo a un archivo de excel.
#
# Nota 1: es posible que logren obtener los links a las noticias sin el dominio: "https://www.lanacion.com.ar/". De ser así, concatenen el dominio a la ruta del link obtenido, tal que se obtenga un link al que se pueda acceder. Es decir, que las cadenas de caracteres finales tendrán la forma: https://www.lanacion.com.ar/*texto_obtenido*)
#
# Nota 2: junto con su entrega, adjunten una captura de la página de noticias al momento de correr su código. Eso servirá al momento de la corrección para verificar que los links obtenidos hacen referencia a las noticias de ese día y hora.

# %%
# Resolver acá
